# %%
url="https://www.google.com/search?q=paniza"

# %%
url="https://www.google.com/search?q=cubo"

# %%
from requests import get
busqueda = get(url)

# %%
busqueda
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(busqueda.content, "html.parser")

# %%
soup.find_all('div', attrs={'class': "cOl4Id"})
# Out:
# [<div class="cOl4Id"><a href="/?sa=X&amp;ved=0ahUKEwiE6quk39ntAhVmvlkKHVcIDhoQOwgC"><span class="V6gwVd">G</span><span class="iWkuvd">o</span><span class="cDrQ7">o</span><span class="V6gwVd">g</span><span class="ntlR9">l</span><span class="iWkuvd tJ3Myc">e</span></a></div>]

# %%
soup.find_all('div')
# Out:
# [<div class="cOl4Id"><a href="/?sa=X&amp;ved=0ahUKEwiE6quk39ntAhVmvlkKHVcIDhoQOwgC"><span class="V6gwVd">G</span><span class="iWkuvd">o</span><span class="cDrQ7">o</span><span class="V6gwVd">g</span><span class="ntlR9">l</span><span class="iWkuvd tJ3Myc">e</span></a></div>,
# ...

# %%
usr_agent = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) '
                      'Chrome/61.0.3163.100 Safari/537.36'}

google_url = 'https://www.google.com/search?q=comida&num=6&hl=es'
response=None
response = get(google_url, headers=usr_agent)

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
c=""
c=soup.find_all('div', attrs={'class': 'g'})

# %%
b=c[:-1]

# %%
 for result in c:
    link = result.find('a', href=True)
    title = result.find('h3')
    
    
    if link and title:
        s= result.span.text
        print (f"s->{s}")
        print (link['href'])
        r= result.find('span', attrs={'class': 'aCOpRe'}).text
        print (r)
        
    print("")

# %%
aCOpRe
bellip=soup.div.find_all('aCOpRe')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-a8dc317e8be5> in <module>
# ----> 1 aCOpRe
#       2 bellip=soup.div.find_all('aCOpRe')
#
# NameError: name 'aCOpRe' is not defined

# %%
b=soup.find_all('span', attrs={'class': 'aCOpRe'})

# %%
b
# Out:
# [<span class="aCOpRe"><span><em>Cubo</em> o hexaedro regular es un poliedro limitado por seis caras cuadradas congruentes. Es uno de los denominados sólidos platónicos. Un <em>cubo</em>, además de ...</span></span>,
#  <span class="aCOpRe"><span>En aritmética y álgebra, el <em>cubo</em> de un número n es la tercera potencia —el resultado de multiplicar por sí mismo dos veces:​. n 3 = n ⋅ n ⋅ n {\displaystyle<wbr/> ...</span></span>,
#  <span class="aCOpRe"><span class="f">9 jul 2019 — </span><span><em>Cubo</em> Un <em>cubo</em> o hexaedro regular es un poliedro regular formado por 6 cuadrados iguales. Desarrollo del <em>cubo</em> Características del <em>cubo</em> ...</span></span>,
#  <span class="aCOpRe"><span>Un <em>cubo</em> o hexaedro es un poliedro regular formado por 6 cuadrados iguales. Desarrollo del <em>Cubo</em> Propiedades del <em>cubo</em> Número de caras: 6. Número de ...</span></span>]

# %%
from googleapiclient.discovery import build   #Import the library
api_key = "my-secret-api-key"
cse_id = "my-secret-custom-search-id "
def google_query(query, api_key, cse_id, **kwargs):
    query_service = build("customsearch", 
                          "v1", 
                          developerKey=api_key
                          )  
    query_results = query_service.cse().list(q=query,    # Query
                                             cx=cse_id,  # CSE ID
                                             **kwargs    
                                             ).execute()
    return query_results['items']
my_results_list = []
my_results = google_query("apple iphone news 2019",
                          api_key, 
                          cse_id, 
                          num = 10
                          )
for result in my_results:
    my_results_list.append(result['link'])
    print(result['link'])
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-3-535caa4195ef> in <module>
#      13     return query_results['items']
#      14 my_results_list = []
# ---> 15 my_results = google_query("apple iphone news 2019",
#      16                           api_key,
#      17                           cse_id,
#
# <ipython-input-3-535caa4195ef> in google_query(query, api_key, cse_id, **kwargs)
#       3 cse_id = "my-secret-custom-search-id "
#       4 def google_query(query, api_key, cse_id, **kwargs):
# ----> 5     query_service = build("customsearch",
#       6                           "v1",
#       7                           developerKey=api_key
#
# ~\AppData\Roaming\Python\Python39\site-packages\googleapiclient\_helpers.py in positional_wrapper(*args, **kwargs)
#     132                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
# ...

# %%
from googlesearch import search
query = "cubo"
my_results_list = []
for i in search(query,        # The query you want to run
                tld = 'com',  # The top level domain
                lang = 'en',  # The language
                num = 4,     # Number of results per page
                start = 0,    # First result to retrieve
                stop = 4,  # Last result to retrieve
                pause = 2.0,  # Lapse between HTTP requests
               ):
    my_results_list.append(i)
    print(i)
# Out:
# https://es.wikipedia.org/wiki/Cubo
# https://es.wikipedia.org/wiki/Cubo#Elementos
# https://es.wikipedia.org/wiki/Cubo#Medidas_y_simetr%C3%ADa
# https://es.wikipedia.org/wiki/Cubo#Simetr%C3%ADa
